# %% [markdown]
# <a href="https://colab.research.google.com/github/buabns/Aulas_PCD/blob/main/aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota = float(input("Digite o valor da nota: "))
if nota < 60:
 print("Sua nota {} é insuficiente! ".format(nota))
# Out:
# Digite o valor da nota: 50
# Sua nota 50.0 é insuficiente!

# %%
nota = float(input("Digite o valor da nota: "))
if nota < 60:
 print("Sua nota {} é insuficiente! ".format(nota))
else:
 print("sua nota {} foi suficiente ".format(nota))
 print ("nota boa")
# Out:
# Digite o valor da nota: 100
# sua nota 100.0 foi suficiente
# nota boa

# %%
nota = float(input("Digite o valor da nota: "))
if nota < 60:
 print("Sua nota {} é insuficiente! ".format(nota))
elif nota > 60 and nota < 75:
 print("sua nota {} foi C! ".format(nota))
elif nota >= 75 and nota < 90:
  print("Sua nota {} foi B! ".format(nota))
else:
  print("Sua nota{} A! ".format(nota))
# Out:
# Digite o valor da nota: 75
# Sua nota 75.0 foi B!

# %%
senha = "112233"
digitado = " "
while (digitado != senha):
  digitado = input("Digite a senha: ")
  if digitado == senha:
    print ("Acesso Liberado")
  else:
    print ("Senha incorreta. Tente novamente")
# Out:
# Digite a senha: 112233
# Acesso Liberado

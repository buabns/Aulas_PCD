# %% [markdown]
# <a href="https://colab.research.google.com/github/buabns/Aulas_PCD/blob/main/Estudo_independente_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DESAFIO 1
alunos = int(input("Quantos alunos sua turma possui? "))

notas = []

for aluno in range(1, alunos + 1):
    nota = int(input(f"Qual a nota do {aluno} aluno? "))
    while nota > 10 or nota < 0:
        print("Forneça uma nota entre 0 e 10!")
        nota = int(input(f"Qual a nota do {aluno} aluno? "))
    notas.append(nota)

def maior_nota(notas):
    return max(notas)

def menor_nota(notas):
    return min(notas)

def media(notas):
    return sum(notas) / len(notas)

def aprovados(notas):
    quantidade = 0

    for nota in notas:
        if nota >= 6:
            quantidade += 1
    return quantidade

def reprovados(notas):
    quantidade = 0

    for nota in notas:
        if nota < 6:
            quantidade += 1
    return quantidade

print()
print("Resultado da turma")
print(f"Maior nota: {maior_nota(notas)}")
print(f"Menor nota: {menor_nota(notas)}")
print(f"Média da turma: {media(notas):.2f}")
print(f"Aprovados: {aprovados(notas)}")
print(f"Reprovados: {reprovados(notas)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2136/386612084.py in <cell line: 0>()
# ----> 1 alunos = int(input("Quantos alunos sua turma possui? "))
#       2
#       3 notas = []
#       4
#       5 for aluno in range(1, alunos + 1):
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#DESAFIO 2
produtos = {}


def cadastrar_produto():
    codigo = int(input("Código do produto: "))
    nome = input("Nome do produto: ")
    preco = float(input("Preço do produto: R$ "))
    quantidade = int(input("Quantidade em estoque: "))
    produtos[codigo] = {
        "nome": nome,
        "preco": preco,
        "quantidade": quantidade
    }

    print("Produto cadastrado com sucesso")


def consultar_produto():
    codigo = int(input("Digite o código do produto: "))
    if codigo in produtos:
        produto = produtos[codigo]
        print(f"\nNome: {produto['nome']}")
        print(f"Preço: R$ {produto['preco']:.2f}")
        print(f"Quantidade: {produto['quantidade']}")
    else:
        print("Produto não encontrado.")


def valor_total_estoque():
    total = 0
    for produto in produtos.values():
        total += produto["preco"] * produto["quantidade"]
    print(f"Valor total do estoque: R$ {total:.2f}")


def maior_valor_unitario():
    if len(produtos) == 0:
        print("Nenhum produto cadastrado.")
        return

    produto_maior = max(
        produtos.values(),
        key=lambda produto: produto["preco"]
    )

    print(f"Produto de maior valor unitário: {produto_maior['nome']}")
    print(f"Preço: R$ {produto_maior['preco']:.2f}")


while True:

    print("    MENU   ")
    print("1 - Cadastrar produto")
    print("2 - Consultar produto")
    print("3 - Calcular valor total do estoque")
    print("4 - Mostrar produto de maior valor unitário")
    print("5 - Sair")

    opcao = int(input("Escolha uma opção: "))

    if opcao == 1:
        cadastrar_produto()

    elif opcao == 2:
        consultar_produto()

    elif opcao == 3:
        valor_total_estoque()

    elif opcao == 4:
        maior_valor_unitario()

    elif opcao == 5:
        print("Programa encerrado.")
        break

    else:
        print("Opção inválida.")
# Out:
#     MENU
# 1 - Cadastrar produto
# 2 - Consultar produto
# 3 - Calcular valor total do estoque
# 4 - Mostrar produto de maior valor unitário
# 5 - Sair
# Escolha uma opção: 1
# Código do produto: 05
# Nome do produto: cebola
# Preço do produto: R$ 5
# Quantidade em estoque: 1
# Produto cadastrado com sucesso
#     MENU
# 1 - Cadastrar produto
# 2 - Consultar produto
# 3 - Calcular valor total do estoque
# 4 - Mostrar produto de maior valor unitário
# 5 - Sair
# Escolha uma opção: 2
# Digite o código do produto: 05
#
# Nome: cebola
# Preço: R$ 5.00
# Quantidade: 1
#     MENU
# 1 - Cadastrar produto
# 2 - Consultar produto
# 3 - Calcular valor total do estoque
# 4 - Mostrar produto de maior valor unitário
# 5 - Sair
# Escolha uma opção: 3
# Valor total do estoque: R$ 5.00
#     MENU
# 1 - Cadastrar produto
# 2 - Consultar produto
# 3 - Calcular valor total do estoque
# 4 - Mostrar produto de maior valor unitário
# 5 - Sair
# ...

# %%
# !git config --global user.name "buabns"
# !git config --global user.email "gtnicolas123@gmail.com"
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com

# !gh auth setup-git
# !git clone https://github.com/buabns/Aulas_PCD.git
# %cd /content/Aulas_PCD
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# (Reading database ... 118419 files and directories currently installed.)
# Preparing to unpack .../archives/gh_2.99.0_amd64.deb ...
# Unpacking gh (2.99.0) over (2.98.0) ...
# Setting up gh (2.99.0) ...
# Processing triggers for man-db (2.10.2-1) ...
#
# ! First copy your one-time code: E58B-F286
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# ! Authentication credentials saved in plain text
# ✓ Logged in as buabns
# Cloning into 'Aulas_PCD'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 78 (delta 34), reused 19 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 26.95 KiB | 5.39 MiB/s, done.
# ...

# %%
# !git add .
# !git commit -m "Desafio 2 Estudo independente"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# To https://github.com/buabns/Aulas_PCD.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/buabns/Aulas_PCD.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

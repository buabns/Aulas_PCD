# %% [markdown]
# <a href="https://colab.research.google.com/github/buabns/Aulas_PCD/blob/main/Atividade_aula09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dia = navegador.find_element(
  By.XPATH,
  "/html/body/div[1]/div/div/div/div/main/div[5]/div/div[2]/div/div[2]/div/div/div/div[2]/div[1]/div/div/div/div[2]/button/div/div[1]/div[1]"
  ).text

tempbaixa = navegador.find_element(
  By.XPATH,
  "/html/body/div[1]/div/div/div/div/main/div[5]/div/div[2]/div/div[2]/div/div/div/div[2]/div[1]/div/div/div/div[2]/button/div/div[2]/div[2]/div[2]"
  ).text

tempalta = navegador.find_element(
  By.XPATH,
  "/html/body/div[1]/div/div/div/div/main/div[5]/div/div[2]/div/div[2]/div/div/div/div[2]/div[1]/div/div/div/div[2]/button/div/div[2]/div[2]/div[1]"
  ).text

print(f"A temperatua do dia {dia} é:\n")
print(f"A temperatua baixa do dia é: {tempbaixa}\n")
print(f"A temperatua alta do dia é: {tempalta}")
# Out:
# A temperatua do dia 24 é:
#
# A temperatua baixa do dia é: 16°
#
# A temperatua alta do dia é: 26°

# %%
# !pip install -q google-colab-selenium
import google_colab_selenium as gs
from selenium.webdriver.common.by import By
from time import sleep
navegador = gs.Chrome()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 69.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 kB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 88.7 MB/s eta 0:00:00
#             <div class="spinner-container">
#                 <div class="spinner" id="369cb97b-acde-44c2-974e-21b4fd04f690-circle"></div>
#                 <div class="spinner-text" id="369cb97b-acde-44c2-974e-21b4fd04f690-text">Preparing environment</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
# ...

# %%
url = (
"https://www.msn.com/pt-br/clima/forecast/in-Ubiretama,Rio-Grande-do-Sul?loc=eyJsIjoiVWJpcmV0YW1hIiwiciI6IlJpbyBHcmFuZGUgZG8gU3VsIiwiYyI6IkJyYXNpbCIsImkiOiJCUiIsInQiOjEwMiwiZyI6InB0LWJyIiwieCI6Ii01NC42ODE2IiwieSI6Ii0yOC4wNDU2In0%3D&weadegreetype=C"
)

# %%
navegador.get(url)
sleep(2)
print("Página:", navegador.title)
# Out:
# Página: Previsão do Tempo para Ubiretama, Rio Grande do Sul | MSN Clima

# %%
botoes = navegador.find_elements(
  By.XPATH,
  "//*[@id='cookieConsent']//button"
  "[contains(., 'Rejeitar Tudo')]"
)

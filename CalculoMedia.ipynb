# %% [markdown]
# <a href="https://colab.research.google.com/github/buabns/Teste/blob/main/CalculoMedia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota1 =  int (input ("Fale a primeira nota: "))
nota2 =  int (input ("Fale a segunda nota: "))
nota3 =  int (input ("Fale a terceira nota: "))
media = (nota1 + nota2 + nota3) / 3
print ("Sua media é: ", media)
# Out:
# Fale a primeira nota: 2
# Fale a segunda nota: 3
# Fale a terceira nota: 4
# Sua media é:  3.0
